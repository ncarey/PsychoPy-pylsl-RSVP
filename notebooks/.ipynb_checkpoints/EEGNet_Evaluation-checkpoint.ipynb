# %%
from SciServer import CasJobs, Files, Authentication
import sys
import os.path
import statistics
from matplotlib import pyplot as plt
import pandas
import numpy as np
import mne
from sklearn.utils import shuffle #pip install --user sklearn


#BELOW is necessary since we are not currently running from project directory
#since we need to import libs from parent dir, need to add parent dir to path
project_path = '/home/idies/workspace/Storage/ncarey/persistent/PULSD/PsychoPy-pylsl-RSVP/'
if project_path not in sys.path:
    sys.path.append(project_path)

import importlib
EEGModels = importlib.import_module("arl-eegmodels.EEGModels")

# %%
class EEGNetWrapper:
    
    def loadSession(self, session_ID):
        print("Querying session {0} from CasJobs".format(session_ID))
        
        info = mne.create_info(self.channel_names, self.recorded_sample_freq, self.channel_types, self.montage)
        info['description'] = '16 channel EEG sessionID {0}'.format(session_ID)
        
        raw_query = "select * from session_eeg where session_ID = {0} order by timestamp".format(session_ID)
        raw_df = CasJobs.executeQuery(sql=raw_query, context=self.casjobs_context)

        raw_data = []
        for index in range(len(self.channel_names)):
            raw_data.append(raw_df[self.channel_names[index]].values)

        custom_raw = mne.io.RawArray(raw_data, info)
        
        # we do this query to get the data reading index at which the stims appear.  IE, instead of 
        # saying stim X was presented at time Y (as it is in the raw data), we want to 
        # say stim X appeared at data reading index Z
        stim_index_query = '''
            with stim_timestamps_index(index_value, timestamp) as (
            select count(*), stim_timestamps.timestamp from session_eeg, stim_timestamps 
            where session_eeg.session_ID = {0} and stim_timestamps.session_ID = {0} and session_eeg.timestamp < stim_timestamps.timestamp 
            group by stim_timestamps.timestamp
            )

            select stim_timestamps_index.index_value, stim_timestamps.stim_ID from stim_timestamps_index, stim_timestamps 
            where stim_timestamps.session_ID = {0} and stim_timestamps.timestamp = stim_timestamps_index.timestamp
            order by stim_timestamps_index.index_value'''.format(session_ID)

        stim_index_df = CasJobs.executeQuery(sql=stim_index_query, context=self.casjobs_context)

        stim_ind = stim_index_df['index_value'].values
        stim_ID = stim_index_df['stim_ID'].values

        events = []
        for i in range(len(stim_ind)):
            events.append([stim_ind[i]+1, 0, stim_ID[i]])
        
        epochs = mne.Epochs(raw=custom_raw, events=events, event_id=self.event_id_dict, tmin=self.epoch_tmin, tmax=self.epoch_tmax)

        # Now we load the epochs into their respective target and distractor arrays of epochs
        # More importantly, we downsample to 128Hz, which is the input sampling rate EEGNet is setup for
        
        #Downsample to 128Hz
        
        epochs.load_data()
        epochs_resampled = epochs.copy().resample(self.resample_rate, npad='auto')

        target_epochs = epochs_resampled[self.target_epoch_names]
        distract_epochs = epochs_resampled[self.distract_epoch_names]
        
        return target_epochs, distract_epochs

            
    def loadTrainingData(self, session_ID):
        target_epochs, distract_epochs = self.loadSession(session_ID)
        
        target_data = target_epochs.get_data()  # len(target_epochs) epochs of 16 channels x 128 readings
        distract_data = distract_epochs.get_data()

        
        if len(self.training_data) == 0:
            self.training_data = np.array(target_data[0], ndmin=4)
            self.training_class = np.array([1,0], ndmin=2)
        else:
            self.training_data = np.append(self.training_data, np.array(target_data[0], ndmin=4), axis=0)
            cur_class = np.array([1,0], ndmin=2)
            self.training_class = np.append(self.training_class, cur_class, axis=0)

        for i in range(1, len(target_data)):
            cur_epoch = np.array(target_data[i], ndmin=4)
            self.training_data = np.append(self.training_data, cur_epoch, axis=0)
            cur_class = np.array([1,0], ndmin=2)
            self.training_class = np.append(self.training_class, cur_class, axis=0)
    
        for i in range(0, len(distract_data)):
            cur_epoch = np.array(distract_data[i], ndmin=4)
            self.training_data = np.append(self.training_data, cur_epoch, axis=0)
            cur_class = np.array([0,1], ndmin=2)
            self.training_class = np.append(self.training_class, cur_class, axis=0)
        
    def loadEvaluationData(self, session_ID):
        target_epochs, distract_epochs = self.loadSession(session_ID)
        
        target_data = target_epochs.get_data()  # len(target_epochs) epochs of 16 channels x 128 readings
        distract_data = distract_epochs.get_data()

        if len(self.eval_data) == 0:
            self.eval_data = np.array(target_data[0], ndmin=4)
            self.eval_class = np.array([1,0], ndmin=2)
        else:
            self.eval_data = np.append(self.eval_data, np.array(target_data[0], ndmin=4), axis=0)
            cur_class = np.array([1,0], ndmin=2)
            self.eval_class = np.append(self.eval_class, cur_class, axis=0)

        for i in range(1, len(target_data)):
            cur_epoch = np.array(target_data[i], ndmin=4)
            self.eval_data = np.append(self.eval_data, cur_epoch, axis=0)
            cur_class = np.array([1,0], ndmin=2)
            self.eval_class = np.append(self.eval_class, cur_class, axis=0)
    
        for i in range(0, len(distract_data)):
            cur_epoch = np.array(distract_data[i], ndmin=4)
            self.eval_data = np.append(self.eval_data, cur_epoch, axis=0)
            cur_class = np.array([0,1], ndmin=2)
            self.eval_class = np.append(self.eval_class, cur_class, axis=0)
            
            
    def fit(self, training_iterations):
        self.fitted = self.model.fit(x=self.training_data, y=self.training_class, epochs=training_iterations) #validation_split=.2

    def predict(self, data_to_predict):
        print(self.model.predict(x=data_to_predict))
        
    def evaluate(self):
        pos_count = 0
        neg_count = 0
        true_pos_count = 0
        false_pos_count = 0
        true_neg_count = 0
        false_neg_count = 0
        
        for i in range(0, len(self.eval_data)):
            #self.predict(np.array(self.eval_data[i], ndmin=4))
            print("True Class: {0}".format(self.eval_class[i]))
            prediction = self.model.predict(x=np.array(self.eval_data[i], ndmin=4))
            print("Prediction: {0}".format(prediction))
            if self.eval_class[i][0] == 1: #positive
                pos_count = pos_count + 1
                if prediction[0][0] > prediction[0][1]: #True Positive
                    true_pos_count = true_pos_count + 1
                else:
                    false_neg_count = false_neg_count + 1
            
            else: #negative
                neg_count = neg_count + 1
                if prediction[0][0] < prediction[0][1]: #True Negative
                    true_neg_count = true_neg_count + 1
                else:
                    false_pos_count = false_pos_count + 1
            
        result = '''True Positives: {0}, True Negatives: {1}, False Positives: {2}, False Negatives: {3}'''.format(true_pos_count, true_neg_count, false_pos_count, false_neg_count)
        print(result)
        
            
    
    def __init__(self):
        
        self.model = EEGModels.EEGNet(nb_classes = 2, Chans=16, Samples=128)
        self.model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])
        
        # MNE-specific information
        self.channel_names = ['F3', 'Fz', 'F4', 'T7', 'C3', 'Cz', 'C4', 'T8', 'Cp3', 'Cp4', 'P3', 'Pz', 'P4', 'PO7', 'PO8', 'Oz']
        self.channel_types = ['eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg','eeg']
        self.recorded_sample_freq = 512
        self.montage = 'standard_1005'
        self.target_epoch_names = ['t_01', 't_02', 't_03', 't_04']
        self.distract_epoch_names = ['d_01', 'd_02', 'd_03', 'd_04', 'd_05', 'd_06', 'd_07', 'd_08', 'd_09', 'd_10']
        self.event_id_dict = dict(t_04=0, t_03=1, t_02=2, t_01=3, d_10=4, d_09=5, d_08=6, d_07=7, d_06=8, d_05=9, d_04=10, d_03=11, d_02=12, d_01=13)
        self.epoch_tmin = 0
        self.epoch_tmax = 1
        self.resample_rate = 128 #desired sample freq in Hz for EEGNet input 
        
        self.casjobs_context = "MyDB"
                
        self.training_data = []
        self.training_class = []
        
        self.eval_data = []
        self.eval_class = []

# %%
EEGNetWrap = EEGNetWrapper()
for i in range(2, 19):  #Need to skip sessions 0, 1 as they are incomplete
    EEGNetWrap.loadTrainingData(i)  
    
EEGNetWrap.fit(training_iterations=30)
EEGNetWrap.loadEvaluationData(19)
# Out:
# Querying session 2 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=81968
#     Range : 0 ... 81967 =      0.000 ...   160.092 secs
# Ready.
# 320 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 320 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 3 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=93728
#     Range : 0 ... 93727 =      0.000 ...   183.061 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 4 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=93856
#     Range : 0 ... 93855 =      0.000 ...   183.311 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 5 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=92752
#     Range : 0 ... 92751 =      0.000 ...   181.154 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 6 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=92784
#     Range : 0 ... 92783 =      0.000 ...   181.217 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 7 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=91968
#     Range : 0 ... 91967 =      0.000 ...   179.623 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 8 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=92240
#     Range : 0 ... 92239 =      0.000 ...   180.154 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 9 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=94224
#     Range : 0 ... 94223 =      0.000 ...   184.029 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 10 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=91408
#     Range : 0 ... 91407 =      0.000 ...   178.529 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 11 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=99296
#     Range : 0 ... 99295 =      0.000 ...   193.936 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 12 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=92912
#     Range : 0 ... 92911 =      0.000 ...   181.467 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 13 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=90512
#     Range : 0 ... 90511 =      0.000 ...   176.779 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 14 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=91056
#     Range : 0 ... 91055 =      0.000 ...   177.842 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 15 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=90384
#     Range : 0 ... 90383 =      0.000 ...   176.529 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 16 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=90912
#     Range : 0 ... 90911 =      0.000 ...   177.561 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 17 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=90880
#     Range : 0 ... 90879 =      0.000 ...   177.498 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Querying session 18 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=91040
#     Range : 0 ... 91039 =      0.000 ...   177.811 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped
# Epoch 1/30
# 6720/6720 [==============================] - 4s 605us/step - loss: 0.4046 - acc: 0.9067
# Epoch 2/30
# 6720/6720 [==============================] - 3s 416us/step - loss: 0.2855 - acc: 0.9159
# Epoch 3/30
# 6720/6720 [==============================] - 3s 412us/step - loss: 0.2577 - acc: 0.9162
# Epoch 4/30
# 6720/6720 [==============================] - 3s 423us/step - loss: 0.2387 - acc: 0.9174
# Epoch 5/30
# 6720/6720 [==============================] - 3s 419us/step - loss: 0.2166 - acc: 0.9220
# Epoch 6/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.1952 - acc: 0.9320
# Epoch 7/30
# 6720/6720 [==============================] - 3s 415us/step - loss: 0.1803 - acc: 0.9384
# Epoch 8/30
# 6720/6720 [==============================] - 3s 414us/step - loss: 0.1660 - acc: 0.9384
# Epoch 9/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.1589 - acc: 0.9406
# Epoch 10/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.1538 - acc: 0.9423
# Epoch 11/30
# 6720/6720 [==============================] - 3s 412us/step - loss: 0.1467 - acc: 0.9470
# Epoch 12/30
# 6720/6720 [==============================] - 3s 414us/step - loss: 0.1446 - acc: 0.9464
# Epoch 13/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.1341 - acc: 0.9513
# Epoch 14/30
# 6720/6720 [==============================] - 3s 419us/step - loss: 0.1277 - acc: 0.9558
# Epoch 15/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.1308 - acc: 0.9536
# Epoch 16/30
# 6720/6720 [==============================] - 3s 421us/step - loss: 0.1244 - acc: 0.9528
# Epoch 17/30
# 6720/6720 [==============================] - 3s 414us/step - loss: 0.1227 - acc: 0.9522
# Epoch 18/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.1195 - acc: 0.9551
# Epoch 19/30
# 6720/6720 [==============================] - 3s 413us/step - loss: 0.1177 - acc: 0.9583
# Epoch 20/30
# 6720/6720 [==============================] - 3s 415us/step - loss: 0.1120 - acc: 0.9586
# Epoch 21/30
# 6720/6720 [==============================] - 3s 415us/step - loss: 0.1101 - acc: 0.9609
# Epoch 22/30
# 6720/6720 [==============================] - 3s 414us/step - loss: 0.1046 - acc: 0.9616
# Epoch 23/30
# 6720/6720 [==============================] - 3s 412us/step - loss: 0.1048 - acc: 0.9643
# Epoch 24/30
# 6720/6720 [==============================] - 3s 418us/step - loss: 0.1039 - acc: 0.9622
# Epoch 25/30
# 6720/6720 [==============================] - 3s 422us/step - loss: 0.0972 - acc: 0.9679
# Epoch 26/30
# 6720/6720 [==============================] - 3s 417us/step - loss: 0.0968 - acc: 0.9647
# Epoch 27/30
# 6720/6720 [==============================] - 3s 413us/step - loss: 0.0946 - acc: 0.9649
# Epoch 28/30
# 6720/6720 [==============================] - 3s 414us/step - loss: 0.0941 - acc: 0.9668
# Epoch 29/30
# 6720/6720 [==============================] - 3s 412us/step - loss: 0.0889 - acc: 0.9667
# Epoch 30/30
# 6720/6720 [==============================] - 3s 414us/step - loss: 0.0894 - acc: 0.9710
# Querying session 19 from CasJobs
# Creating RawArray with float64 data, n_channels=16, n_times=92672
#     Range : 0 ... 92671 =      0.000 ...   180.998 secs
# Ready.
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 400 events and 513 original time points ...
# 0 bad epochs dropped

# %%
EEGNetWrap.evaluate()
# Out:
# True Class: [1 0]
# Prediction: [[0.15294406 0.8470559 ]]
# True Class: [1 0]
# Prediction: [[0.5175245 0.4824755]]
# True Class: [1 0]
# Prediction: [[0.6166121 0.3833879]]
# True Class: [1 0]
# Prediction: [[0.28656048 0.71343946]]
# True Class: [1 0]
# Prediction: [[0.28004044 0.7199596 ]]
# True Class: [1 0]
# Prediction: [[0.9513215  0.04867853]]
# True Class: [1 0]
# Prediction: [[0.45058697 0.5494131 ]]
# True Class: [1 0]
# Prediction: [[0.92401445 0.07598552]]
# True Class: [1 0]
# Prediction: [[0.12993388 0.87006605]]
# True Class: [1 0]
# Prediction: [[0.9594573  0.04054275]]
# True Class: [1 0]
# Prediction: [[0.93278795 0.06721205]]
# True Class: [1 0]
# Prediction: [[0.67130375 0.32869628]]
# True Class: [1 0]
# Prediction: [[0.7053491  0.29465094]]
# True Class: [1 0]
# Prediction: [[0.86414844 0.13585153]]
# True Class: [1 0]
# Prediction: [[0.7823204  0.21767959]]
# True Class: [1 0]
# Prediction: [[0.4125423 0.5874577]]
# True Class: [1 0]
# Prediction: [[0.8773711  0.12262891]]
# True Class: [1 0]
# Prediction: [[0.78081906 0.21918094]]
# True Class: [1 0]
# Prediction: [[0.82032657 0.17967342]]
# True Class: [1 0]
# Prediction: [[0.86083233 0.1391676 ]]
# True Class: [1 0]
# Prediction: [[0.2826493 0.7173507]]
# True Class: [1 0]
# Prediction: [[0.22884922 0.77115077]]
# True Class: [1 0]
# Prediction: [[0.1541756  0.84582436]]
# True Class: [1 0]
# Prediction: [[0.71792334 0.28207666]]
# True Class: [1 0]
# Prediction: [[0.9568148  0.04318519]]
# True Class: [1 0]
# Prediction: [[0.54236716 0.45763284]]
# True Class: [1 0]
# Prediction: [[0.9085178  0.09148226]]
# True Class: [1 0]
# Prediction: [[0.79805785 0.2019421 ]]
# True Class: [1 0]
# Prediction: [[0.7424798 0.2575202]]
# True Class: [1 0]
# Prediction: [[0.9248941  0.07510588]]
# True Class: [1 0]
# Prediction: [[0.9185599  0.08144005]]
# True Class: [1 0]
# Prediction: [[0.90197223 0.09802771]]
# True Class: [1 0]
# Prediction: [[0.7091234  0.29087666]]
# True Class: [1 0]
# Prediction: [[0.9361835  0.06381642]]
# True Class: [0 1]
# Prediction: [[0.00484096 0.9951591 ]]
# True Class: [0 1]
# Prediction: [[0.00667784 0.9933222 ]]
# True Class: [0 1]
# Prediction: [[0.01551558 0.98448443]]
# True Class: [0 1]
# Prediction: [[0.01049642 0.9895036 ]]
# True Class: [0 1]
# Prediction: [[9.756460e-04 9.990244e-01]]
# True Class: [0 1]
# Prediction: [[0.30426276 0.69573724]]
# True Class: [0 1]
# Prediction: [[0.00449803 0.99550194]]
# True Class: [0 1]
# Prediction: [[0.00370919 0.9962908 ]]
# True Class: [0 1]
# Prediction: [[0.00109234 0.9989077 ]]
# True Class: [0 1]
# Prediction: [[0.00722219 0.99277776]]
# True Class: [0 1]
# Prediction: [[0.00218251 0.9978175 ]]
# True Class: [0 1]
# Prediction: [[0.04989831 0.9501017 ]]
# True Class: [0 1]
# Prediction: [[0.00807783 0.99192214]]
# True Class: [0 1]
# Prediction: [[5.912757e-04 9.994087e-01]]
# True Class: [0 1]
# Prediction: [[0.00150115 0.9984988 ]]
# True Class: [0 1]
# Prediction: [[0.02151034 0.9784897 ]]
# True Class: [0 1]
# Prediction: [[0.02172185 0.97827816]]
# True Class: [0 1]
# Prediction: [[0.0023753 0.9976247]]
# True Class: [0 1]
# Prediction: [[0.00550519 0.99449474]]
# True Class: [0 1]
# Prediction: [[3.4236669e-04 9.9965763e-01]]
# True Class: [0 1]
# Prediction: [[0.00298336 0.99701667]]
# True Class: [0 1]
# Prediction: [[4.0610827e-04 9.9959391e-01]]
# True Class: [0 1]
# Prediction: [[9.4527000e-04 9.9905473e-01]]
# True Class: [0 1]
# Prediction: [[0.05750679 0.9424932 ]]
# True Class: [0 1]
# Prediction: [[0.01306494 0.986935  ]]
# True Class: [0 1]
# Prediction: [[0.00219934 0.99780065]]
# True Class: [0 1]
# Prediction: [[0.0019178  0.99808216]]
# True Class: [0 1]
# Prediction: [[0.04121839 0.95878166]]
# True Class: [0 1]
# Prediction: [[0.05055723 0.9494428 ]]
# True Class: [0 1]
# Prediction: [[0.0029311  0.99706894]]
# True Class: [0 1]
# Prediction: [[0.00126787 0.99873215]]
# True Class: [0 1]
# Prediction: [[0.010874  0.9891261]]
# True Class: [0 1]
# Prediction: [[0.00306936 0.99693066]]
# True Class: [0 1]
# Prediction: [[0.02277405 0.9772259 ]]
# True Class: [0 1]
# Prediction: [[0.00112694 0.99887305]]
# True Class: [0 1]
# Prediction: [[0.00718827 0.99281174]]
# True Class: [0 1]
# Prediction: [[1.8134924e-04 9.9981862e-01]]
# True Class: [0 1]
# Prediction: [[0.01303141 0.9869686 ]]
# True Class: [0 1]
# Prediction: [[0.09310329 0.9068967 ]]
# True Class: [0 1]
# Prediction: [[0.0072325  0.99276745]]
# True Class: [0 1]
# Prediction: [[0.00860955 0.99139047]]
# True Class: [0 1]
# Prediction: [[0.11383548 0.88616455]]
# True Class: [0 1]
# Prediction: [[0.00467379 0.99532616]]
# True Class: [0 1]
# Prediction: [[0.03731773 0.96268225]]
# True Class: [0 1]
# Prediction: [[0.0587721 0.9412279]]
# True Class: [0 1]
# Prediction: [[0.00114429 0.9988557 ]]
# True Class: [0 1]
# Prediction: [[0.01774014 0.9822598 ]]
# True Class: [0 1]
# Prediction: [[0.0048167 0.9951833]]
# True Class: [0 1]
# Prediction: [[0.03620623 0.9637937 ]]
# True Class: [0 1]
# Prediction: [[0.00164951 0.9983505 ]]
# True Class: [0 1]
# Prediction: [[0.00311806 0.99688196]]
# True Class: [0 1]
# Prediction: [[0.00418332 0.99581665]]
# True Class: [0 1]
# Prediction: [[5.7974172e-05 9.9994206e-01]]
# True Class: [0 1]
# Prediction: [[0.00637983 0.9936202 ]]
# True Class: [0 1]
# Prediction: [[0.43744382 0.56255615]]
# True Class: [0 1]
# Prediction: [[0.01319257 0.9868074 ]]
# True Class: [0 1]
# Prediction: [[0.00735599 0.992644  ]]
# True Class: [0 1]
# Prediction: [[0.00558015 0.9944199 ]]
# True Class: [0 1]
# Prediction: [[0.05038825 0.9496117 ]]
# True Class: [0 1]
# Prediction: [[0.00611031 0.9938897 ]]
# True Class: [0 1]
# Prediction: [[2.719855e-04 9.997280e-01]]
# True Class: [0 1]
# Prediction: [[0.01334095 0.98665905]]
# True Class: [0 1]
# Prediction: [[0.01857512 0.9814249 ]]
# True Class: [0 1]
# Prediction: [[0.02758766 0.9724123 ]]
# True Class: [0 1]
# Prediction: [[0.08147218 0.91852784]]
# True Class: [0 1]
# Prediction: [[0.00227001 0.99772996]]
# True Class: [0 1]
# Prediction: [[0.04629529 0.95370466]]
# True Class: [0 1]
# Prediction: [[0.07371558 0.92628443]]
# True Class: [0 1]
# Prediction: [[0.060765 0.939235]]
# True Class: [0 1]
# Prediction: [[0.00598258 0.99401736]]
# True Class: [0 1]
# Prediction: [[0.03816944 0.96183056]]
# True Class: [0 1]
# Prediction: [[0.00551213 0.99448794]]
# True Class: [0 1]
# Prediction: [[0.03626551 0.9637345 ]]
# True Class: [0 1]
# Prediction: [[0.022201 0.977799]]
# True Class: [0 1]
# Prediction: [[0.01213943 0.9878606 ]]
# True Class: [0 1]
# Prediction: [[0.00946959 0.99053043]]
# True Class: [0 1]
# Prediction: [[0.00156257 0.99843746]]
# True Class: [0 1]
# Prediction: [[0.01471552 0.9852845 ]]
# True Class: [0 1]
# Prediction: [[0.00187383 0.9981262 ]]
# True Class: [0 1]
# Prediction: [[0.08237407 0.91762596]]
# True Class: [0 1]
# Prediction: [[0.02500195 0.974998  ]]
# True Class: [0 1]
# Prediction: [[0.04180793 0.9581921 ]]
# True Class: [0 1]
# Prediction: [[0.00456929 0.9954307 ]]
# True Class: [0 1]
# Prediction: [[0.01217686 0.9878231 ]]
# True Class: [0 1]
# Prediction: [[0.00197442 0.99802566]]
# True Class: [0 1]
# Prediction: [[0.00169035 0.9983096 ]]
# True Class: [0 1]
# Prediction: [[0.01831793 0.9816821 ]]
# True Class: [0 1]
# Prediction: [[0.00984548 0.9901545 ]]
# True Class: [0 1]
# Prediction: [[0.00676923 0.9932308 ]]
# True Class: [0 1]
# Prediction: [[0.01770516 0.9822948 ]]
# True Class: [0 1]
# Prediction: [[0.0015233 0.9984767]]
# True Class: [0 1]
# Prediction: [[8.4867573e-04 9.9915135e-01]]
# True Class: [0 1]
# Prediction: [[0.00176698 0.99823296]]
# True Class: [0 1]
# Prediction: [[0.01245654 0.98754346]]
# True Class: [0 1]
# Prediction: [[2.4100405e-04 9.9975902e-01]]
# True Class: [0 1]
# Prediction: [[0.00627905 0.993721  ]]
# True Class: [0 1]
# Prediction: [[0.00621965 0.9937803 ]]
# True Class: [0 1]
# Prediction: [[0.3358922 0.6641078]]
# True Class: [0 1]
# Prediction: [[0.02964934 0.9703507 ]]
# True Class: [0 1]
# Prediction: [[0.00801088 0.9919891 ]]
# True Class: [0 1]
# Prediction: [[0.01994336 0.9800567 ]]
# True Class: [0 1]
# Prediction: [[0.01706483 0.9829352 ]]
# True Class: [0 1]
# Prediction: [[0.21534   0.7846599]]
# True Class: [0 1]
# Prediction: [[0.01494714 0.9850529 ]]
# True Class: [0 1]
# Prediction: [[0.17309655 0.82690346]]
# True Class: [0 1]
# Prediction: [[3.0022740e-04 9.9969983e-01]]
# True Class: [0 1]
# Prediction: [[3.189432e-04 9.996811e-01]]
# True Class: [0 1]
# Prediction: [[0.00100494 0.998995  ]]
# True Class: [0 1]
# Prediction: [[0.13728365 0.8627164 ]]
# True Class: [0 1]
# Prediction: [[0.01193631 0.98806363]]
# True Class: [0 1]
# Prediction: [[0.00334119 0.9966588 ]]
# True Class: [0 1]
# Prediction: [[0.01584532 0.9841547 ]]
# True Class: [0 1]
# Prediction: [[0.00441154 0.9955884 ]]
# True Class: [0 1]
# Prediction: [[0.00724786 0.9927522 ]]
# True Class: [0 1]
# Prediction: [[0.01362878 0.9863712 ]]
# True Class: [0 1]
# Prediction: [[0.19779903 0.8022009 ]]
# True Class: [0 1]
# Prediction: [[0.01074426 0.9892558 ]]
# True Class: [0 1]
# Prediction: [[0.01175271 0.98824733]]
# True Class: [0 1]
# Prediction: [[6.5594475e-04 9.9934405e-01]]
# True Class: [0 1]
# Prediction: [[0.0036924 0.9963076]]
# True Class: [0 1]
# Prediction: [[0.131527   0.86847305]]
# True Class: [0 1]
# Prediction: [[0.04548289 0.9545172 ]]
# True Class: [0 1]
# Prediction: [[0.01408408 0.9859159 ]]
# True Class: [0 1]
# Prediction: [[5.4488779e-04 9.9945515e-01]]
# True Class: [0 1]
# Prediction: [[0.05364879 0.94635123]]
# True Class: [0 1]
# Prediction: [[0.01849736 0.9815027 ]]
# True Class: [0 1]
# Prediction: [[0.01201414 0.9879859 ]]
# True Class: [0 1]
# Prediction: [[0.04244202 0.957558  ]]
# True Class: [0 1]
# Prediction: [[0.00267581 0.9973241 ]]
# True Class: [0 1]
# Prediction: [[5.3799717e-04 9.9946207e-01]]
# True Class: [0 1]
# Prediction: [[0.00255307 0.9974469 ]]
# True Class: [0 1]
# Prediction: [[0.02108873 0.9789113 ]]
# True Class: [0 1]
# Prediction: [[7.1780017e-04 9.9928218e-01]]
# True Class: [0 1]
# Prediction: [[0.03812942 0.9618706 ]]
# True Class: [0 1]
# Prediction: [[5.754061e-04 9.994246e-01]]
# True Class: [0 1]
# Prediction: [[7.716524e-05 9.999229e-01]]
# True Class: [0 1]
# Prediction: [[0.00361614 0.9963839 ]]
# True Class: [0 1]
# Prediction: [[0.00127617 0.9987238 ]]
# True Class: [0 1]
# Prediction: [[0.00148498 0.99851507]]
# True Class: [0 1]
# Prediction: [[0.18217671 0.8178233 ]]
# True Class: [0 1]
# Prediction: [[5.2038093e-05 9.9994791e-01]]
# True Class: [0 1]
# Prediction: [[6.3937384e-04 9.9936062e-01]]
# True Class: [0 1]
# Prediction: [[5.8174442e-04 9.9941826e-01]]
# True Class: [0 1]
# Prediction: [[0.00293238 0.99706763]]
# True Class: [0 1]
# Prediction: [[0.06646641 0.9335336 ]]
# True Class: [0 1]
# Prediction: [[2.4449261e-04 9.9975556e-01]]
# True Class: [0 1]
# Prediction: [[0.00238689 0.9976131 ]]
# True Class: [0 1]
# Prediction: [[0.00324374 0.99675626]]
# True Class: [0 1]
# Prediction: [[6.2196283e-04 9.9937797e-01]]
# True Class: [0 1]
# Prediction: [[0.00733258 0.9926675 ]]
# True Class: [0 1]
# Prediction: [[1.8012139e-04 9.9981993e-01]]
# True Class: [0 1]
# Prediction: [[0.00141001 0.99858993]]
# True Class: [0 1]
# Prediction: [[8.9662225e-04 9.9910337e-01]]
# True Class: [0 1]
# Prediction: [[0.01936118 0.9806388 ]]
# True Class: [0 1]
# Prediction: [[0.03401517 0.96598476]]
# True Class: [0 1]
# Prediction: [[0.0108811  0.98911893]]
# True Class: [0 1]
# Prediction: [[0.00211077 0.9978892 ]]
# True Class: [0 1]
# Prediction: [[0.02877778 0.9712223 ]]
# True Class: [0 1]
# Prediction: [[0.00754818 0.99245185]]
# True Class: [0 1]
# Prediction: [[0.00148975 0.9985102 ]]
# True Class: [0 1]
# Prediction: [[0.01780681 0.98219323]]
# True Class: [0 1]
# Prediction: [[0.00284243 0.9971576 ]]
# True Class: [0 1]
# Prediction: [[0.01228696 0.987713  ]]
# True Class: [0 1]
# Prediction: [[0.00170033 0.99829966]]
# True Class: [0 1]
# Prediction: [[0.04167102 0.95832896]]
# True Class: [0 1]
# Prediction: [[0.00850801 0.991492  ]]
# True Class: [0 1]
# Prediction: [[0.00129073 0.9987093 ]]
# True Class: [0 1]
# Prediction: [[0.11542901 0.884571  ]]
# True Class: [0 1]
# Prediction: [[0.00191543 0.99808455]]
# True Class: [0 1]
# Prediction: [[7.250022e-04 9.992750e-01]]
# True Class: [0 1]
# Prediction: [[0.08041397 0.919586  ]]
# True Class: [0 1]
# Prediction: [[0.00746532 0.99253464]]
# True Class: [0 1]
# Prediction: [[0.01159197 0.988408  ]]
# True Class: [0 1]
# Prediction: [[0.00625665 0.99374336]]
# True Class: [0 1]
# Prediction: [[0.02428191 0.975718  ]]
# True Class: [0 1]
# Prediction: [[0.0088194 0.9911806]]
# True Class: [0 1]
# Prediction: [[0.20988287 0.79011714]]
# True Class: [0 1]
# Prediction: [[0.01405372 0.98594624]]
# True Class: [0 1]
# Prediction: [[0.02105583 0.9789442 ]]
# True Class: [0 1]
# Prediction: [[0.02274241 0.97725755]]
# True Class: [0 1]
# Prediction: [[0.00187166 0.99812835]]
# True Class: [0 1]
# Prediction: [[8.0922130e-04 9.9919075e-01]]
# True Class: [0 1]
# Prediction: [[0.00450346 0.9954965 ]]
# True Class: [0 1]
# Prediction: [[0.02972279 0.9702772 ]]
# True Class: [0 1]
# Prediction: [[0.00569035 0.99430966]]
# True Class: [0 1]
# Prediction: [[7.1786594e-04 9.9928218e-01]]
# True Class: [0 1]
# Prediction: [[0.0010092  0.99899083]]
# True Class: [0 1]
# Prediction: [[0.00662268 0.9933774 ]]
# True Class: [0 1]
# Prediction: [[3.8817988e-04 9.9961179e-01]]
# True Class: [0 1]
# Prediction: [[0.00840878 0.9915912 ]]
# True Class: [0 1]
# Prediction: [[0.04014266 0.95985734]]
# True Class: [0 1]
# Prediction: [[0.03485237 0.9651477 ]]
# True Class: [0 1]
# Prediction: [[3.6396724e-04 9.9963605e-01]]
# True Class: [0 1]
# Prediction: [[0.13188966 0.8681103 ]]
# True Class: [0 1]
# Prediction: [[0.00449048 0.9955095 ]]
# True Class: [0 1]
# Prediction: [[0.0076611 0.9923389]]
# True Class: [0 1]
# Prediction: [[0.00211166 0.9978884 ]]
# True Class: [0 1]
# Prediction: [[2.0802743e-04 9.9979204e-01]]
# True Class: [0 1]
# Prediction: [[0.14059027 0.8594097 ]]
# True Class: [0 1]
# Prediction: [[0.00279118 0.9972088 ]]
# True Class: [0 1]
# Prediction: [[0.0034246 0.9965754]]
# True Class: [0 1]
# Prediction: [[0.01476311 0.9852368 ]]
# True Class: [0 1]
# Prediction: [[0.01074537 0.9892546 ]]
# True Class: [0 1]
# Prediction: [[0.02705894 0.97294104]]
# True Class: [0 1]
# Prediction: [[0.02698903 0.973011  ]]
# True Class: [0 1]
# Prediction: [[0.00367458 0.99632543]]
# True Class: [0 1]
# Prediction: [[6.438510e-04 9.993562e-01]]
# True Class: [0 1]
# Prediction: [[9.1214775e-04 9.9908781e-01]]
# True Class: [0 1]
# Prediction: [[0.00193208 0.9980679 ]]
# True Class: [0 1]
# Prediction: [[0.00409049 0.9959096 ]]
# True Class: [0 1]
# Prediction: [[0.00581451 0.9941855 ]]
# True Class: [0 1]
# Prediction: [[0.02963958 0.97036046]]
# True Class: [0 1]
# Prediction: [[0.00533785 0.9946622 ]]
# True Class: [0 1]
# Prediction: [[0.00409739 0.9959026 ]]
# True Class: [0 1]
# Prediction: [[0.05956098 0.94043905]]
# True Class: [0 1]
# Prediction: [[0.00229192 0.9977081 ]]
# True Class: [0 1]
# Prediction: [[0.01506999 0.98493004]]
# True Class: [0 1]
# Prediction: [[0.0018931  0.99810684]]
# True Class: [0 1]
# Prediction: [[2.6697808e-04 9.9973303e-01]]
# True Class: [0 1]
# Prediction: [[7.881893e-04 9.992118e-01]]
# True Class: [0 1]
# Prediction: [[0.00339239 0.99660766]]
# True Class: [0 1]
# Prediction: [[0.0578681  0.94213194]]
# True Class: [0 1]
# Prediction: [[0.04554843 0.95445156]]
# True Class: [0 1]
# Prediction: [[4.1213437e-04 9.9958783e-01]]
# True Class: [0 1]
# Prediction: [[0.01050313 0.9894968 ]]
# True Class: [0 1]
# Prediction: [[0.22373393 0.7762661 ]]
# True Class: [0 1]
# Prediction: [[0.0014172  0.99858284]]
# True Class: [0 1]
# Prediction: [[0.01400438 0.9859956 ]]
# True Class: [0 1]
# Prediction: [[0.02681992 0.9731801 ]]
# True Class: [0 1]
# Prediction: [[5.3860206e-04 9.9946135e-01]]
# True Class: [0 1]
# Prediction: [[0.00655606 0.99344397]]
# True Class: [0 1]
# Prediction: [[0.02613008 0.9738699 ]]
# True Class: [0 1]
# Prediction: [[1.4052124e-04 9.9985945e-01]]
# True Class: [0 1]
# Prediction: [[5.544354e-04 9.994455e-01]]
# True Class: [0 1]
# Prediction: [[0.01569363 0.98430634]]
# True Class: [0 1]
# Prediction: [[0.05643735 0.9435627 ]]
# True Class: [0 1]
# Prediction: [[0.00314149 0.9968585 ]]
# True Class: [0 1]
# Prediction: [[0.00826014 0.99173987]]
# True Class: [0 1]
# Prediction: [[0.0105093 0.9894907]]
# True Class: [0 1]
# Prediction: [[0.01548177 0.98451823]]
# True Class: [0 1]
# Prediction: [[0.00694103 0.9930589 ]]
# True Class: [0 1]
# Prediction: [[0.00184737 0.99815255]]
# True Class: [0 1]
# Prediction: [[0.00400826 0.99599177]]
# True Class: [0 1]
# Prediction: [[0.00741952 0.9925804 ]]
# True Class: [0 1]
# Prediction: [[0.00183835 0.9981616 ]]
# True Class: [0 1]
# Prediction: [[0.07709165 0.9229083 ]]
# True Class: [0 1]
# Prediction: [[0.02116732 0.9788327 ]]
# True Class: [0 1]
# Prediction: [[0.16568683 0.8343132 ]]
# True Class: [0 1]
# Prediction: [[0.0134794  0.98652065]]
# True Class: [0 1]
# Prediction: [[0.13071981 0.8692802 ]]
# True Class: [0 1]
# Prediction: [[2.8700562e-04 9.9971300e-01]]
# True Class: [0 1]
# Prediction: [[0.00373456 0.9962655 ]]
# True Class: [0 1]
# Prediction: [[6.1092176e-04 9.9938905e-01]]
# True Class: [0 1]
# Prediction: [[0.01061267 0.9893874 ]]
# True Class: [0 1]
# Prediction: [[0.05001047 0.94998956]]
# True Class: [0 1]
# Prediction: [[0.00251334 0.9974866 ]]
# True Class: [0 1]
# Prediction: [[6.592963e-04 9.993407e-01]]
# True Class: [0 1]
# Prediction: [[4.5340825e-04 9.9954659e-01]]
# True Class: [0 1]
# Prediction: [[0.09108326 0.9089167 ]]
# True Class: [0 1]
# Prediction: [[1.7729402e-04 9.9982268e-01]]
# True Class: [0 1]
# Prediction: [[5.3438032e-04 9.9946564e-01]]
# True Class: [0 1]
# Prediction: [[0.51129735 0.48870265]]
# True Class: [0 1]
# Prediction: [[0.00170673 0.9982932 ]]
# True Class: [0 1]
# Prediction: [[0.00366075 0.9963393 ]]
# True Class: [0 1]
# Prediction: [[0.05532398 0.94467604]]
# True Class: [0 1]
# Prediction: [[0.00982514 0.9901749 ]]
# True Class: [0 1]
# Prediction: [[0.01439695 0.9856031 ]]
# True Class: [0 1]
# Prediction: [[0.03130214 0.9686979 ]]
# True Class: [0 1]
# Prediction: [[5.8091694e-04 9.9941909e-01]]
# True Class: [0 1]
# Prediction: [[4.0634157e-04 9.9959368e-01]]
# True Class: [0 1]
# Prediction: [[0.05527622 0.9447238 ]]
# True Class: [0 1]
# Prediction: [[0.00169207 0.99830794]]
# True Class: [0 1]
# Prediction: [[0.07198752 0.92801243]]
# True Class: [0 1]
# Prediction: [[0.00189272 0.9981073 ]]
# True Class: [0 1]
# Prediction: [[0.03055582 0.96944416]]
# True Class: [0 1]
# Prediction: [[0.05452767 0.94547236]]
# True Class: [0 1]
# Prediction: [[7.023987e-05 9.999298e-01]]
# True Class: [0 1]
# Prediction: [[0.00461269 0.9953874 ]]
# True Class: [0 1]
# Prediction: [[0.18263571 0.8173643 ]]
# True Class: [0 1]
# Prediction: [[0.00420721 0.99579275]]
# True Class: [0 1]
# Prediction: [[0.04302564 0.9569744 ]]
# True Class: [0 1]
# Prediction: [[0.05463415 0.9453658 ]]
# True Class: [0 1]
# Prediction: [[0.0012049  0.99879503]]
# True Class: [0 1]
# Prediction: [[0.00236399 0.99763596]]
# True Class: [0 1]
# Prediction: [[0.05893987 0.9410601 ]]
# True Class: [0 1]
# Prediction: [[1.2147851e-04 9.9987853e-01]]
# True Class: [0 1]
# Prediction: [[0.00642601 0.99357396]]
# True Class: [0 1]
# Prediction: [[0.00566096 0.99433905]]
# True Class: [0 1]
# Prediction: [[0.00489532 0.9951047 ]]
# True Class: [0 1]
# Prediction: [[5.5218930e-04 9.9944776e-01]]
# True Class: [0 1]
# Prediction: [[0.05673431 0.9432657 ]]
# True Class: [0 1]
# Prediction: [[0.01027729 0.9897227 ]]
# True Class: [0 1]
# Prediction: [[0.0076864  0.99231356]]
# True Class: [0 1]
# Prediction: [[0.0110676 0.9889324]]
# True Class: [0 1]
# Prediction: [[7.468581e-04 9.992531e-01]]
# True Class: [0 1]
# Prediction: [[0.00745881 0.9925412 ]]
# True Class: [0 1]
# Prediction: [[0.01141924 0.98858076]]
# True Class: [0 1]
# Prediction: [[0.00224146 0.9977585 ]]
# True Class: [0 1]
# Prediction: [[0.07999852 0.92000145]]
# True Class: [0 1]
# Prediction: [[8.6699612e-04 9.9913305e-01]]
# True Class: [0 1]
# Prediction: [[5.4884923e-04 9.9945110e-01]]
# True Class: [0 1]
# Prediction: [[2.9014284e-04 9.9970978e-01]]
# True Class: [0 1]
# Prediction: [[0.01368936 0.9863107 ]]
# True Class: [0 1]
# Prediction: [[0.00440458 0.9955954 ]]
# True Class: [0 1]
# Prediction: [[0.01017443 0.98982555]]
# True Class: [0 1]
# Prediction: [[0.01894401 0.9810559 ]]
# True Class: [0 1]
# Prediction: [[0.00294958 0.9970504 ]]
# True Class: [0 1]
# Prediction: [[0.00443226 0.99556774]]
# True Class: [0 1]
# Prediction: [[0.00256713 0.9974329 ]]
# True Class: [0 1]
# Prediction: [[0.00227873 0.99772125]]
# True Class: [0 1]
# Prediction: [[0.01148278 0.98851717]]
# True Class: [0 1]
# Prediction: [[0.00169014 0.99830985]]
# True Class: [0 1]
# Prediction: [[0.37013558 0.6298644 ]]
# True Class: [0 1]
# Prediction: [[0.01126929 0.9887307 ]]
# True Class: [0 1]
# Prediction: [[0.00357625 0.9964238 ]]
# True Class: [0 1]
# Prediction: [[0.00269454 0.9973054 ]]
# True Class: [0 1]
# Prediction: [[0.0061757  0.99382436]]
# True Class: [0 1]
# Prediction: [[0.00153451 0.99846554]]
# True Class: [0 1]
# Prediction: [[0.00131516 0.9986848 ]]
# True Class: [0 1]
# Prediction: [[0.01661269 0.98338723]]
# True Class: [0 1]
# Prediction: [[0.00635534 0.9936447 ]]
# True Class: [0 1]
# Prediction: [[0.01689958 0.9831004 ]]
# True Class: [0 1]
# Prediction: [[0.00140479 0.9985952 ]]
# True Class: [0 1]
# Prediction: [[0.04305684 0.9569432 ]]
# True Class: [0 1]
# Prediction: [[0.00157928 0.9984207 ]]
# True Class: [0 1]
# Prediction: [[3.3989293e-04 9.9966013e-01]]
# True Class: [0 1]
# Prediction: [[4.6590850e-04 9.9953413e-01]]
# True Class: [0 1]
# Prediction: [[0.61413765 0.38586232]]
# True Class: [0 1]
# Prediction: [[2.2454478e-04 9.9977547e-01]]
# True Class: [0 1]
# Prediction: [[0.00290406 0.99709594]]
# True Class: [0 1]
# Prediction: [[0.14721332 0.85278666]]
# True Class: [0 1]
# Prediction: [[0.00413924 0.99586076]]
# True Class: [0 1]
# Prediction: [[0.00272848 0.9972715 ]]
# True Class: [0 1]
# Prediction: [[0.04098612 0.95901394]]
# True Class: [0 1]
# Prediction: [[0.00213579 0.9978642 ]]
# True Class: [0 1]
# Prediction: [[0.01140239 0.98859763]]
# True Class: [0 1]
# Prediction: [[6.439286e-04 9.993561e-01]]
# True Class: [0 1]
# Prediction: [[3.9264435e-04 9.9960738e-01]]
# True Class: [0 1]
# Prediction: [[0.02804354 0.97195643]]
# True Class: [0 1]
# Prediction: [[7.768476e-04 9.992231e-01]]
# True Class: [0 1]
# Prediction: [[0.08335675 0.9166432 ]]
# True Class: [0 1]
# Prediction: [[0.09159979 0.9084002 ]]
# True Class: [0 1]
# Prediction: [[0.08711988 0.9128801 ]]
# True Class: [0 1]
# Prediction: [[0.00323362 0.9967663 ]]
# True Class: [0 1]
# Prediction: [[0.01039461 0.9896054 ]]
# True Class: [0 1]
# Prediction: [[0.07163727 0.9283628 ]]
# True Class: [0 1]
# Prediction: [[0.02607418 0.9739258 ]]
# True Class: [0 1]
# Prediction: [[4.3344364e-04 9.9956650e-01]]
# True Class: [0 1]
# Prediction: [[0.00203722 0.99796283]]
# True Class: [0 1]
# Prediction: [[0.11694052 0.8830595 ]]
# True Class: [0 1]
# Prediction: [[9.1808988e-04 9.9908185e-01]]
# True Class: [0 1]
# Prediction: [[0.08064477 0.9193552 ]]
# True Class: [0 1]
# Prediction: [[0.00172821 0.9982718 ]]
# True Class: [0 1]
# Prediction: [[0.00591211 0.99408793]]
# True Class: [0 1]
# Prediction: [[0.2589952 0.7410048]]
# True Class: [0 1]
# Prediction: [[5.3995108e-04 9.9946004e-01]]
# True Class: [0 1]
# Prediction: [[0.02801887 0.9719811 ]]
# True Class: [0 1]
# Prediction: [[0.09402362 0.90597636]]
# True Class: [0 1]
# Prediction: [[0.00118764 0.99881244]]
# True Class: [0 1]
# Prediction: [[4.5989887e-04 9.9954009e-01]]
# True Class: [0 1]
# Prediction: [[4.7583322e-04 9.9952424e-01]]
# True Class: [0 1]
# Prediction: [[0.00433785 0.99566215]]
# True Class: [0 1]
# Prediction: [[0.09882992 0.90117   ]]
# True Class: [0 1]
# Prediction: [[0.03254783 0.9674522 ]]
# True Class: [0 1]
# Prediction: [[0.01273891 0.98726106]]
# True Class: [0 1]
# Prediction: [[0.06246303 0.93753695]]
# True Positives: 25, True Negatives: 364, False Positives: 2, False Negatives9

# %%
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(EEGNetWrap.training_class),
                                                 EEGNetWrap.training_class)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-29-8f6e4a1f51d8> in <module>
#       2 class_weights = class_weight.compute_class_weight('balanced',
#       3                                                  np.unique(EEGNetWrap.training_class),
# ----> 4                                                  EEGNetWrap.training_class)
#       5
#
# ~/.local/lib/python3.5/site-packages/sklearn/utils/class_weight.py in compute_class_weight(class_weight, classes, y)
#      39     from ..preprocessing import LabelEncoder
#      40
# ---> 41     if set(y) - set(classes):
#      42         raise ValueError("classes should include all valid labels that can "
#      43                          "be in y")
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
y_ints = [y.argmax() for y in EEGNetWrap.training_class]
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(EEGNetWrap.training_class),
                                                 y_ints)
class_weights
# Out:
# array([5.93639576, 0.54598635])
