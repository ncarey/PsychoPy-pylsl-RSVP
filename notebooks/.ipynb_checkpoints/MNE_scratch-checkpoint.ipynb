# %%
import sys
import os.path
import statistics
from matplotlib import pyplot as plt
import pandas
from SciServer import CasJobs
import numpy as np
import mne

# %%
# Names for each channel
channel_names = ['F3', 'Fz', 'F4', 'T7', 'C3', 'Cz', 'C4', 'T8', 'Cp3', 'Cp4', 'P3', 'Pz', 'P4', 'PO7', 'PO8', 'Oz']

# The type (mag, grad, eeg, eog, misc, ...) of each channel
channel_types = ['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg']

# The sampling rate of the recording
sfreq = 512  # in Hertz

# The EEG channels use the standard naming strategy.
# By supplying the 'montage' parameter, approximate locations
# will be added for them
montage = 'standard_1005'

# Initialize required fields
info = mne.create_info(channel_names, sfreq, channel_types, montage)

# Add some more information
info['description'] = 'test'
#info['bads'] = ['Pz']  # Names of bad channels

query = "select * from session_eeg where session_ID = {0} order by timestamp".format(session_ID)
df = CasJobs.executeQuery(sql=query, context="MyDB")

data = []
for index in range(len(channel_names)):
    data.append(df[channel_names[index]].values)

custom_raw = mne.io.RawArray(data, info)
print(custom_raw)
# Out:
# Creating RawArray with float64 data, n_channels=16, n_times=93728
#     Range : 0 ... 93727 =      0.000 ...   183.061 secs
# Ready.
# <RawArray  |  None, n_channels x n_times : 16 x 93728 (183.1 sec), ~11.5 MB, data loaded>

# %%
stim_index_query = '''
with stim_timestamps_index(index_value, timestamp) as (
select count(*), stim_timestamps.timestamp from session_eeg, stim_timestamps 
where session_eeg.session_ID = 3 and stim_timestamps.session_ID = 3 and session_eeg.timestamp < stim_timestamps.timestamp 
group by stim_timestamps.timestamp
)

select stim_timestamps_index.index_value, stim_timestamps.stim_ID from stim_timestamps_index, stim_timestamps 
where stim_timestamps.session_ID = 3 and stim_timestamps.timestamp = stim_timestamps_index.timestamp
  order by stim_timestamps_index.index_value
'''

stim_index_df = CasJobs.executeQuery(sql=stim_index_query, context="MyDB")

# %%
stim_ind = stim_index_df['index_value'].values
stim_ID = stim_index_df['stim_ID'].values

events = []
for i in range(len(stim_ind)):
    events.append([stim_ind[i], 0, stim_ID[i]])
# Out:
# [[4626, 0, 6],
#  [4762, 0, 8],
#  [4901, 0, 8],
#  [5039, 0, 7],
#  [5178, 0, 4],
#  [5317, 0, 5],
#  [5456, 0, 2],
#  [5595, 0, 12],
#  [5734, 0, 11],
#  [5873, 0, 11],
#  [6011, 0, 4],
#  [6151, 0, 12],
#  [6290, 0, 11],
#  [6429, 0, 7],
#  [6566, 0, 11],
#  [6703, 0, 10],
#  [6842, 0, 11],
#  [6982, 0, 6],
#  [7121, 0, 7],
#  [7257, 0, 3],
#  [7396, 0, 4],
#  [7535, 0, 5],
#  [7674, 0, 11],
#  [7814, 0, 5],
#  [7953, 0, 5],
#  [10140, 0, 12],
#  [10277, 0, 12],
#  [10413, 0, 10],
#  [10550, 0, 4],
#  [10689, 0, 10],
#  [10828, 0, 11],
#  [10967, 0, 13],
#  [11107, 0, 0],
#  [11246, 0, 9],
#  [11385, 0, 13],
#  [11525, 0, 12],
#  [11664, 0, 4],
#  [11803, 0, 9],
#  [11942, 0, 12],
#  [12079, 0, 12],
#  [12217, 0, 8],
#  [12355, 0, 11],
#  [12494, 0, 3],
#  [12633, 0, 10],
#  [12772, 0, 8],
#  [12910, 0, 5],
#  [13049, 0, 12],
#  [13188, 0, 11],
#  [13328, 0, 6],
#  [13467, 0, 8],
#  [15654, 0, 13],
#  [15791, 0, 10],
#  [15928, 0, 7],
#  [16065, 0, 7],
#  [16204, 0, 7],
#  [16342, 0, 4],
#  [16482, 0, 13],
#  [16620, 0, 10],
#  [16759, 0, 9],
#  [16897, 0, 2],
#  [17036, 0, 7],
#  [17176, 0, 4],
#  [17315, 0, 5],
#  [17454, 0, 13],
#  [17593, 0, 6],
#  [17733, 0, 7],
#  [17872, 0, 8],
#  [18011, 0, 4],
#  [18150, 0, 13],
#  [18289, 0, 9],
#  [18429, 0, 2],
#  [18568, 0, 9],
#  [18706, 0, 9],
#  [18845, 0, 12],
#  [18984, 0, 12],
#  [21171, 0, 13],
#  [21310, 0, 7],
#  [21450, 0, 11],
#  [21589, 0, 10],
#  [21727, 0, 10],
#  [21865, 0, 0],
#  [22005, 0, 7],
#  [22144, 0, 4],
#  [22282, 0, 13],
#  [22419, 0, 7],
#  [22558, 0, 7],
#  [22697, 0, 9],
#  [22837, 0, 6],
#  [22975, 0, 9],
#  [23114, 0, 4],
#  [23253, 0, 4],
#  [23392, 0, 11],
#  [23530, 0, 8],
#  [23669, 0, 3],
#  [23808, 0, 11],
#  [23947, 0, 4],
#  [24086, 0, 11],
#  [24225, 0, 4],
#  [24365, 0, 7],
#  [24504, 0, 5],
#  [26691, 0, 11],
#  [26829, 0, 12],
#  [26969, 0, 7],
#  [27107, 0, 4],
#  [27247, 0, 10],
#  [27386, 0, 1],
#  [27524, 0, 6],
#  [27664, 0, 10],
#  [27803, 0, 5],
#  [27942, 0, 10],
#  [28080, 0, 10],
#  [28220, 0, 10],
#  [28357, 0, 10],
#  [28497, 0, 11],
#  [28636, 0, 9],
#  [28774, 0, 4],
#  [28910, 0, 10],
#  [29048, 0, 10],
#  [29185, 0, 5],
#  [29322, 0, 12],
#  [29459, 0, 3],
#  [29596, 0, 5],
#  [29733, 0, 4],
#  [29871, 0, 4],
#  [30008, 0, 4],
#  [32193, 0, 10],
#  [32331, 0, 9],
#  [32468, 0, 9],
#  [32607, 0, 12],
#  [32746, 0, 12],
#  [32885, 0, 6],
#  [33024, 0, 8],
#  [33164, 0, 12],
#  [33303, 0, 2],
#  [33440, 0, 5],
#  [33576, 0, 5],
#  [33713, 0, 5],
#  [33850, 0, 12],
#  [33987, 0, 8],
#  [34123, 0, 9],
#  [34260, 0, 12],
#  [34396, 0, 12],
#  [34535, 0, 9],
#  [34675, 0, 5],
#  [34814, 0, 6],
#  [34953, 0, 6],
#  [35093, 0, 11],
#  [35232, 0, 3],
#  [35371, 0, 11],
#  [35510, 0, 4],
#  [37698, 0, 4],
#  [37835, 0, 12],
#  [37973, 0, 10],
#  [38113, 0, 4],
#  [38252, 0, 5],
#  [38391, 0, 0],
#  [38530, 0, 11],
#  [38667, 0, 10],
#  [38804, 0, 12],
#  [38942, 0, 4],
#  [39079, 0, 11],
#  [39216, 0, 11],
#  [39353, 0, 13],
#  [39492, 0, 7],
#  [39629, 0, 11],
#  [39768, 0, 12],
#  [39907, 0, 1],
#  [40047, 0, 12],
#  [40184, 0, 4],
#  [40323, 0, 12],
#  [40463, 0, 7],
#  [40602, 0, 9],
#  [40741, 0, 11],
#  [40881, 0, 13],
#  [41020, 0, 12],
#  [43206, 0, 10],
#  [43343, 0, 12],
#  [43480, 0, 7],
#  [43618, 0, 6],
#  [43755, 0, 11],
#  [43892, 0, 5],
#  [44030, 0, 7],
#  [44168, 0, 4],
#  [44307, 0, 0],
#  [44446, 0, 10],
#  [44584, 0, 9],
#  [44721, 0, 10],
#  [44859, 0, 4],
#  [44996, 0, 6],
#  [45133, 0, 8],
#  [45271, 0, 8],
#  [45408, 0, 8],
#  [45546, 0, 10],
#  [45683, 0, 2],
#  [45820, 0, 11],
#  [45957, 0, 13],
#  [46094, 0, 5],
#  [46232, 0, 9],
#  [46369, 0, 5],
#  [46506, 0, 6],
#  [48692, 0, 10],
#  [48829, 0, 8],
#  [48966, 0, 9],
#  [49104, 0, 8],
#  [49241, 0, 11],
#  [49378, 0, 9],
#  [49515, 0, 6],
#  [49653, 0, 9],
#  [49790, 0, 8],
#  [49927, 0, 4],
#  [50065, 0, 7],
#  [50205, 0, 10],
#  [50342, 0, 12],
#  [50479, 0, 9],
#  [50616, 0, 13],
#  [50755, 0, 10],
#  [50895, 0, 13],
#  [51034, 0, 8],
#  [51172, 0, 4],
#  [51312, 0, 1],
#  [51451, 0, 5],
#  [51589, 0, 6],
#  [51727, 0, 12],
#  [51867, 0, 5],
#  [52006, 0, 6],
#  [54193, 0, 10],
#  [54333, 0, 4],
#  [54472, 0, 11],
#  [54611, 0, 12],
#  [54749, 0, 6],
#  [54889, 0, 11],
#  [55028, 0, 9],
#  [55166, 0, 4],
#  [55304, 0, 13],
#  [55443, 0, 4],
#  [55582, 0, 0],
#  [55721, 0, 13],
#  [55859, 0, 6],
#  [55999, 0, 12],
#  [56139, 0, 6],
#  [56277, 0, 7],
#  [56416, 0, 8],
#  [56556, 0, 8],
#  [56695, 0, 8],
#  [56834, 0, 10],
#  [56974, 0, 2],
#  [57113, 0, 7],
#  [57253, 0, 7],
#  [57391, 0, 8],
#  [57528, 0, 13],
#  [59713, 0, 6],
#  [59850, 0, 9],
#  [59987, 0, 11],
#  [60123, 0, 11],
#  [60260, 0, 9],
#  [60396, 0, 8],
#  [60533, 0, 4],
#  [60670, 0, 13],
#  [60806, 0, 2],
#  [60943, 0, 5],
#  [61080, 0, 7],
#  [61218, 0, 11],
#  [61355, 0, 10],
#  [61494, 0, 10],
#  [61634, 0, 8],
#  [61773, 0, 8],
#  [61911, 0, 10],
#  [62050, 0, 7],
#  [62190, 0, 0],
#  [62328, 0, 11],
#  [62466, 0, 8],
#  [62605, 0, 10],
#  [62744, 0, 11],
#  [62883, 0, 13],
#  [63021, 0, 11],
#  [65206, 0, 13],
#  [65343, 0, 11],
#  [65480, 0, 8],
#  [65618, 0, 12],
#  [65755, 0, 6],
#  [65892, 0, 4],
#  [66030, 0, 10],
#  [66166, 0, 3],
#  [66303, 0, 7],
#  [66440, 0, 11],
#  [66577, 0, 12],
#  [66713, 0, 10],
#  [66851, 0, 4],
#  [66989, 0, 8],
#  [67127, 0, 7],
#  [67266, 0, 6],
#  [67405, 0, 7],
#  [67544, 0, 12],
#  [67684, 0, 0],
#  [67823, 0, 13],
#  [67962, 0, 12],
#  [68100, 0, 13],
#  [68239, 0, 12],
#  [68379, 0, 10],
#  [68518, 0, 5],
#  [70705, 0, 4],
#  [70843, 0, 8],
#  [70979, 0, 7],
#  [71116, 0, 7],
#  [71252, 0, 4],
#  [71389, 0, 7],
#  [71526, 0, 7],
#  [71664, 0, 2],
#  [71804, 0, 12],
#  [71942, 0, 5],
#  [72082, 0, 12],
#  [72221, 0, 13],
#  [72360, 0, 12],
#  [72500, 0, 5],
#  [72639, 0, 9],
#  [72778, 0, 13],
#  [72917, 0, 6],
#  [73057, 0, 7],
#  [73195, 0, 12],
#  [73334, 0, 12],
#  [73474, 0, 2],
#  [73614, 0, 8],
#  [73752, 0, 9],
#  [73891, 0, 12],
#  [74031, 0, 12],
#  [76217, 0, 9],
#  [76357, 0, 10],
#  [76496, 0, 7],
#  [76635, 0, 9],
#  [76774, 0, 6],
#  [76913, 0, 9],
#  [77052, 0, 11],
#  [77192, 0, 4],
#  [77331, 0, 4],
#  [77470, 0, 0],
#  [77609, 0, 11],
#  [77748, 0, 5],
#  [77888, 0, 6],
#  [78027, 0, 9],
#  [78164, 0, 13],
#  [78303, 0, 4],
#  [78442, 0, 6],
#  [78582, 0, 5],
#  [78719, 0, 9],
#  [78858, 0, 9],
#  [78998, 0, 13],
#  [79137, 0, 1],
#  [79276, 0, 12],
#  [79415, 0, 7],
#  [79555, 0, 7],
#  [81742, 0, 10],
#  [81878, 0, 5],
#  [82015, 0, 7],
#  [82152, 0, 4],
#  [82291, 0, 12],
#  [82431, 0, 8],
#  [82570, 0, 12],
#  [82709, 0, 11],
#  [82849, 0, 0],
#  [82988, 0, 12],
#  [83127, 0, 12],
#  [83266, 0, 13],
#  [83405, 0, 12],
#  [83543, 0, 9],
#  [83683, 0, 13],
#  [83822, 0, 5],
#  [83960, 0, 8],
#  [84100, 0, 12],
#  [84239, 0, 13],
#  [84378, 0, 12],
#  [84517, 0, 4],
#  [84657, 0, 5],
#  [84797, 0, 12],
#  [84935, 0, 3],
#  [85075, 0, 5],
#  [87262, 0, 11],
#  [87400, 0, 8],
#  [87537, 0, 12],
#  [87674, 0, 9],
#  [87810, 0, 6],
#  [87947, 0, 0],
#  [88086, 0, 6],
#  [88226, 0, 7],
#  [88365, 0, 8],
#  [88504, 0, 6],
#  [88644, 0, 7],
#  [88783, 0, 7],
#  [88922, 0, 4],
#  [89061, 0, 4],
#  [89199, 0, 7],
#  [89338, 0, 11],
#  [89476, 0, 7],
#  [89615, 0, 5],
#  [89755, 0, 11],
#  [89893, 0, 8],
#  [90030, 0, 12],
#  [90169, 0, 1],
#  [90308, 0, 9],
#  [90447, 0, 5],
#  [90586, 0, 6]]

# %%
event_id = dict(t_04=0, t_03=1, t_02=2, t_01=3, d_10=4, d_09=5, d_08=6, d_07=7, d_06=8, d_05=9, d_04=10, d_03=11, d_02=12, d_01=13)

epochs = mne.Epochs(raw=custom_raw, events=events, event_id=event_id, tmin=-.1, tmax=.6)
# Out:
# 400 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated

# %%
epochs['t_01', 't_02', 't_03', 't_04'].average().plot(time_unit='s')

# %%
epochs['d_01', 'd_02', 'd_03', 'd_04', 'd_05', 'd_06', 'd_07', 'd_08', 'd_09', 'd_10'].average().plot(time_unit='s')
